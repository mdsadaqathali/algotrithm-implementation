# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsadaqathali/algotrithm-implementation/blob/main/predict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def predict(model,X):
    return model.predict(X)
